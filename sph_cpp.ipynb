# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')
x = df['x'].values
y = df['y'].values
cell = df['cell'].values

# %%
plt.scatter(x, y, marker='o', c=cell)
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Cell index as a color for each particle')
plt.show()
