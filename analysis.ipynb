# %%
import matplotlib.pyplot as plt
import numpy as np
from tools import *
from IPython.display import HTML
from IPython.display import Video

# %%
filename = "all_output.bin"
positions, types, drag_force = read_all_output(filename)

# %%
anim = animate_types(positions[::10], types[::10], interval=100)
# Out:
# Frame 1 done

# %%
anim.save("figures/temp.mp4")
# Out:
# Frame 1001 done

# %%
v0 = 1
central_radius = 0.5
rho0 = 1
print(np.mean(drag_force)*2/(v0**2*rho0*2*central_radius))
# Out:
# nan
